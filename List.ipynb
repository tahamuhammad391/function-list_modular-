# %%
Taha= ["Hello",123,1.34,{1:1}]
#        0      1    2     3

Taha[0]
# Out:
# 'Hello'

# %%
type(Taha[0])
# Out:
# str

# %%
Taha.append("rafay")

# %%
Taha
# Out:
# ['Hello', 123, 1.34, {1: 1}, 'rafay']

# %%
Taha.append("waqas")

# %%
Taha.append("rafay")

# %%
Taha.append("rafay")

# %%
Taha.append("waqas")

# %%
Taha.count("rafay")
# Out:
# 3

# %%
Taha
# Out:
# ['Hello', 123, 1.34, {1: 1}, 'rafay', 'waqas', 'rafay', 'rafay', 'waqas']

# %%
Taha.count("waqas")
# Out:
# 2

# %%
type(Taha[4])
# Out:
# str
