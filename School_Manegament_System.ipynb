# %%
# School Management System

roll[]
def admin():
    nos= int(input("Enter a number of student you want to add"))
    for i in range(nos+1):
        rollStd= f"{i}-2026"
        roll.append(rollStd)
    print(f"{nos} Roll Number has been generated")
# Out:
#   Cell In[3], line 3
#     roll[]
#          ^
# SyntaxError: invalid syntax

# %% [raw]
# roll[]

# %%
admin()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 admin()
#
# NameError: name 'admin' is not defined

# %%
# School Management System

roll=[]
def admin():
    nos= int(input("Enter a number of student you want to add"))
    for i in range(nos+1):
        rollStd= f"{i}-2026"
        roll.append(rollStd)
    print(f"{nos} Roll Number has been generated")
# Out:
#   Cell In[1], line 3
#     roll[]
#          ^
# SyntaxError: invalid syntax

# %%
# School Management System

roll=[]
def admin():
    nos= int(input("Enter a number of student you want to add"))
    for i in range(nos+1):
        rollStd= f"{i}-2026"
        roll.append(rollStd)
    print(f"{nos} Roll Number has been generated")

# %%
admin()
# Out:
# Enter a number of student you want to add 10
# 10 Roll Number has been generated

# %%
roll[]
# Out:
#   Cell In[5], line 1
#     roll[]
#          ^
# SyntaxError: invalid syntax

# %%
roll
# Out:
# ['0-2026',
#  '1-2026',
#  '2-2026',
#  '3-2026',
#  '4-2026',
#  '5-2026',
#  '6-2026',
#  '7-2026',
#  '8-2026',
#  '9-2026',
#  '10-2026']

# %%
admin()
# Out:
# Enter a number of student you want to add 3

# %%
admin()
# Out:
# Enter a number of student you want to add 2

# %%
admin()
# Out:
# Enter a number of student you want to add 3
# 3 Roll Number has been generated
